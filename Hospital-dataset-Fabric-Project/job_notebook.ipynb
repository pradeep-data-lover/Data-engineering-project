# %%
from datetime import datetime

# Dynamic values
#data_source = ""
#source_tablename = ""
#rows_copied = ""  # Example row count
#watermark = ""  # Example watermark
load_date = datetime.utcnow()  # Current UTC time

# Construct the query
query = f"""
INSERT INTO load_logs(data_source, tablename, numberofrowscopied, watermarkcolumnname, loaddate)
VALUES ('{data_source}', '{source_tablename}', {rows_copied}, '{watermark}', '{load_date}')
"""
spark.sql(query)  # For debugging
